# %% [raw]
# ALCOHOL EDA AND VISUALIZATION

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
       
df = pd.read_csv("Data/gapminder_alcohol.csv")

# %%
df.head()
# Out:
#        country  alcconsumption  incomeperperson  suicideper100th  employrate  \
# 0  Afghanistan            0.03              NaN         6.684385   55.700001
# 1      Albania            7.29      1914.996551         7.699330   51.400002
# 2      Algeria            0.69      2231.993335         4.848770   50.500000
# 3      Andorra           10.17     21943.339900         5.362179         NaN
# 4       Angola            5.57      1381.004268        14.554677   75.699997
#
#    urbanrate
# 0      24.04
# 1      46.72
# 2      65.22
# 3      88.92
# 4      56.70

# %%
df.describe()
# Out:
#        alcconsumption  incomeperperson  suicideper100th  employrate  \
# count      187.000000       190.000000       191.000000  178.000000
# mean         6.689412      8740.966076         9.640839   58.635955
# std          4.899617     14262.809083         6.300178   10.519454
# min          0.030000       103.775857         0.201449   32.000000
# 25%          2.625000       748.245151         4.988449   51.225000
# 50%          5.920000      2553.496056         8.262893   58.699999
# 75%          9.925000      9379.891166        12.328551   64.975000
# max         23.010000    105147.437700        35.752872   83.199997
#
#         urbanrate
# count  203.000000
# mean    56.769360
# std     23.844933
# min     10.400000
# 25%     36.830000
# 50%     57.940000
# 75%     74.210000
# max    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          213 non-null    object
#  1   alcconsumption   187 non-null    float64
#  2   incomeperperson  190 non-null    float64
#  3   suicideper100th  191 non-null    float64
#  4   employrate       178 non-null    float64
#  5   urbanrate        203 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 10.1+ KB

# %%
df.dropna(inplace=True)

# %% [raw]
# DISTRIBUTION OF DATA

# %%
sns.distplot(df['alcconsumption'], color='black')
# Out:
# C:\Users\guddu\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcconsumption', ylabel='Density'>

# %%
sns.boxplot(data=df, x='alcconsumption', color='grey')
# Out:
# <AxesSubplot:xlabel='alcconsumption'>

# %%
sns.distplot(df['incomeperperson'], color='purple')
# Out:
# C:\Users\guddu\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='incomeperperson', ylabel='Density'>

# %%
sns.boxplot(data = df, x='incomeperperson', color='purple')
# Out:
# <AxesSubplot:xlabel='incomeperperson'>

# %%
sns.distplot(df['suicideper100th'], color='orange')
# Out:
# C:\Users\guddu\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='suicideper100th', ylabel='Density'>

# %%
sns.boxplot(data=df, x='suicideper100th', color='orange')
# Out:
# <AxesSubplot:xlabel='suicideper100th'>

# %%
sns.distplot(df['employrate'],color='red')
# Out:
# C:\Users\guddu\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='employrate', ylabel='Density'>

# %%
sns.boxplot(data=df, x='employrate',color='red')
# Out:
# <AxesSubplot:xlabel='employrate'>

# %%
sns.distplot(df['urbanrate'], color='green')
# Out:
# C:\Users\guddu\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='urbanrate', ylabel='Density'>

# %%
sns.boxplot(data=df, x='urbanrate',color='lightgreen')
# Out:
# <AxesSubplot:xlabel='urbanrate'>

# %% [raw]
# CORRELATION BETWEEN COLUMNS:

# %%
correlations = df.corr(method='pearson')
sns.heatmap(correlations,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
sns.set_style("darkgrid")
sns.lineplot(data=df, x='alcconsumption', y='suicideper100th')
# Out:
# <AxesSubplot:xlabel='alcconsumption', ylabel='suicideper100th'>

# %%
sns.set_style("darkgrid")
sns.lineplot(data=df, x='alcconsumption', y='incomeperperson')
# Out:
# <AxesSubplot:xlabel='alcconsumption', ylabel='incomeperperson'>

# %%
sns.kdeplot(x=df.alcconsumption, y=df.suicideper100th, cmap="Reds",shade=True, bw_adjust=.5)
plt.show()

# %%
sns.set_style("darkgrid")
sns.lineplot(data=df, x="suicideper100th", y="incomeperperson")
# Out:
# <AxesSubplot:xlabel='suicideper100th', ylabel='incomeperperson'>

# %% [raw]
# Major Inference - Suicide Rate And Alcohol Consumption Are Significantly Correlated

# %% [raw]
# COUNTRY-WISE ANALYSIS

# %% [raw]
# SUICIDE RATE PER 100K PEOPLE

# %%
print("Country With Highest Suicide Rate Per 100K Persons")
df[df["suicideper100th"]==df["suicideper100th"].max()]["country"]
# Out:
# Country With Highest Suicide Rate Per 100K Persons
# 80    Guyana
# Name: country, dtype: object

# %%
print("Country With Lowest Suicide Rate Per 100K Persons")
df[df["suicideper100th"]==df["suicideper100th"].min()]["country"]
# Out:
# Country With Lowest Suicide Rate Per 100K Persons
# 95    Jordan
# Name: country, dtype: object

# %% [raw]
# ALCOHOL CONSUMPTION PER ADULT

# %%
print("Country With Highest Alcohol Consumption Per Capita")
df[df["alcconsumption"]==df["alcconsumption"].max()]["country"]
# Out:
# Country With Highest Alcohol Consumption Per Capita
# 126    Moldova
# Name: country, dtype: object

# %%
print("Country With Lowest Alcohol Consumption Per Capita")
df[df["alcconsumption"]==df["alcconsumption"].min()]["country"]
# Out:
# Country With Lowest Alcohol Consumption Per Capita
# 146    Pakistan
# Name: country, dtype: object

# %% [raw]
# TOP 10 COUNTRIES WITH HIGHEST SUICIDE RATES

# %%
dfscs = df.sort_values(ascending=False, by="suicideper100th")
dfscs["country"].head(10)
# Out:
# 80          Guyana
# 110      Lithuania
# 180      Sri Lanka
# 159         Russia
# 16         Belarus
# 103           Laos
# 96      Kazakhstan
# 100    Korea, Rep.
# 182       Suriname
# 104         Latvia
# Name: country, dtype: object

# %% [raw]
# TOP 10 COUNTRIES WITH LOWEST SUICIDE RATES

# %%
dfscs = df.sort_values(ascending=True, by="suicideper100th")
dfscs["country"].head(10)
# Out:
# 95                   Jordan
# 186                   Syria
# 26                   Brunei
# 11               Azerbaijan
# 201    United Arab Emirates
# 81                    Haiti
# 68                  Georgia
# 151                    Peru
# 55                    Egypt
# 152             Philippines
# Name: country, dtype: object

# %% [raw]
# TOP 10 COUNTRIES WITH HIGHEST ALCOHOL CONSUMPTION

# %%
dfscs=df.sort_values(ascending=False, by="alcconsumption")
dfscs["country"].head(10)
# Out:
# 126        Moldova
# 100    Korea, Rep.
# 16         Belarus
# 200        Ukraine
# 59         Estonia
# 49      Czech Rep.
# 199         Uganda
# 110      Lithuania
# 159         Russia
# 158        Romania
# Name: country, dtype: object

# %% [raw]
# TOP 10 COUNTRIES WITH LOWEST ALCOHOL CONSUMPTION

# %%
dfscs=df.sort_values(ascending=True, by="alcconsumption")
dfscs["country"].head(10)
# Out:
# 146        Pakistan
# 108           Libya
# 122      Mauritania
# 14       Bangladesh
# 210     Yemen, Rep.
# 40          Comoros
# 55            Egypt
# 141           Niger
# 167    Saudi Arabia
# 89             Iraq
# Name: country, dtype: object

# %% [raw]
# TOP 10 COUNTRIES WITH HIGHEST EMPLOYMENT:

# %%
dfscs=df.sort_values(ascending=False, by="employrate")
dfscs["country"].head(10)
# Out:
# 199          Uganda
# 29          Burundi
# 114      Madagascar
# 78           Guinea
# 28     Burkina Faso
# 60         Ethiopia
# 160          Rwanda
# 30         Cambodia
# 189        Tanzania
# 103            Laos
# Name: country, dtype: object

# %% [raw]
# TOP 10 COUNTRIES WITH LOWEST EMPLOYMENT:

# %%
dfscs=df.sort_values(ascending=True, by="employrate")
dfscs["country"].head(10)
# Out:
# 113            Macedonia, FYR
# 89                       Iraq
# 95                     Jordan
# 210               Yemen, Rep.
# 7                     Armenia
# 178              South Africa
# 23     Bosnia and Herzegovina
# 195                   Tunisia
# 133                   Namibia
# 55                      Egypt
# Name: country, dtype: object
